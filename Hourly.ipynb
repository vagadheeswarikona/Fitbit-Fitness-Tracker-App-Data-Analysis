# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
data5=pd.read_csv('/content/drive/MyDrive/hourlyCalories_merged.csv')
data6=pd.read_csv('/content/drive/MyDrive/hourlyIntensities_merged.csv')
data7=pd.read_csv('/content/drive/MyDrive/hourlySteps_merged.csv')

# %%
data5.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %%
data5.dtypes
# Out:
# Id               int64
# ActivityHour    object
# Calories         int64
# dtype: object

# %%
data5.duplicated().sum()
# Out:
# 0

# %%
data5.isna().sum()
# Out:
# Id              0
# ActivityHour    0
# Calories        0
# dtype: int64

# %%
data5['ActivityHour']=pd.to_datetime(data5['ActivityHour'])
# Out:
# <ipython-input-19-4b928f9faccf>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data5['ActivityHour']=pd.to_datetime(data5['ActivityHour'])

# %%
data5.head()
# Out:
#            Id        ActivityHour  Calories
# 0  1503960366 2016-04-12 00:00:00        81
# 1  1503960366 2016-04-12 01:00:00        61
# 2  1503960366 2016-04-12 02:00:00        59
# 3  1503960366 2016-04-12 03:00:00        47
# 4  1503960366 2016-04-12 04:00:00        48

# %%
data5.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# Calories                 int64
# dtype: object

# %%
data5['Date'] = pd.to_datetime(data5['ActivityHour']).dt.date
data5['Time'] = pd.to_datetime(data5['ActivityHour']).dt.time

# %%
data5.head()
# Out:
#            Id        ActivityHour  Calories        Date      Time
# 0  1503960366 2016-04-12 00:00:00        81  2016-04-12  00:00:00
# 1  1503960366 2016-04-12 01:00:00        61  2016-04-12  01:00:00
# 2  1503960366 2016-04-12 02:00:00        59  2016-04-12  02:00:00
# 3  1503960366 2016-04-12 03:00:00        47  2016-04-12  03:00:00
# 4  1503960366 2016-04-12 04:00:00        48  2016-04-12  04:00:00

# %%
data5['Date']=pd.to_datetime(data5['Date'])

# %%
data5.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# Calories                 int64
# Date            datetime64[ns]
# Time                    object
# dtype: object

# %%
data5['Hours'] = pd.to_datetime(data5['Time'], format='%H:%M:%S').dt.hour

# %%
data5.head()
# Out:
#            Id        ActivityHour  Calories       Date      Time  Hours
# 0  1503960366 2016-04-12 00:00:00        81 2016-04-12  00:00:00      0
# 1  1503960366 2016-04-12 01:00:00        61 2016-04-12  01:00:00      1
# 2  1503960366 2016-04-12 02:00:00        59 2016-04-12  02:00:00      2
# 3  1503960366 2016-04-12 03:00:00        47 2016-04-12  03:00:00      3
# 4  1503960366 2016-04-12 04:00:00        48 2016-04-12  04:00:00      4

# %%
data5.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# Calories                 int64
# Date            datetime64[ns]
# Time                    object
# Hours                    int32
# dtype: object

# %%
data5.drop(['ActivityHour','Time'],axis=1,inplace=True)

# %%
data5.head()
# Out:
#            Id  Calories       Date  Hours
# 0  1503960366        81 2016-04-12      0
# 1  1503960366        61 2016-04-12      1
# 2  1503960366        59 2016-04-12      2
# 3  1503960366        47 2016-04-12      3
# 4  1503960366        48 2016-04-12      4

# %%
data5.shape
# Out:
# (22099, 4)

# %%
data5.duplicated().sum()
# Out:
# 0

# %%
data6.head()
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20              0.33
# 1  1503960366   4/12/2016 1:00:00 AM               8              0.13
# 2  1503960366   4/12/2016 2:00:00 AM               7              0.12
# 3  1503960366   4/12/2016 3:00:00 AM               0              0.00
# 4  1503960366   4/12/2016 4:00:00 AM               0              0.00

# %%
data6.dtypes
# Out:
# Id                    int64
# ActivityHour         object
# TotalIntensity        int64
# AverageIntensity    float64
# dtype: object

# %%
data6.duplicated().sum()
# Out:
# 0

# %%
data6.isna().sum()
# Out:
# Id                  0
# ActivityHour        0
# TotalIntensity      0
# AverageIntensity    0
# dtype: int64

# %%
data6['ActivityHour']=pd.to_datetime(data6['ActivityHour'])
# Out:
# <ipython-input-41-9d6734c842d5>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data6['ActivityHour']=pd.to_datetime(data6['ActivityHour'])

# %%
data6.head()
# Out:
#            Id        ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366 2016-04-12 00:00:00              20              0.33
# 1  1503960366 2016-04-12 01:00:00               8              0.13
# 2  1503960366 2016-04-12 02:00:00               7              0.12
# 3  1503960366 2016-04-12 03:00:00               0              0.00
# 4  1503960366 2016-04-12 04:00:00               0              0.00

# %%
data6['Date'] = pd.to_datetime(data6['ActivityHour']).dt.date
data6['Time'] = pd.to_datetime(data6['ActivityHour']).dt.time

# %%
data6.head()
# Out:
#            Id        ActivityHour  TotalIntensity  AverageIntensity  \
# 0  1503960366 2016-04-12 00:00:00              20              0.33
# 1  1503960366 2016-04-12 01:00:00               8              0.13
# 2  1503960366 2016-04-12 02:00:00               7              0.12
# 3  1503960366 2016-04-12 03:00:00               0              0.00
# 4  1503960366 2016-04-12 04:00:00               0              0.00
#
#          Date      Time
# 0  2016-04-12  00:00:00
# 1  2016-04-12  01:00:00
# 2  2016-04-12  02:00:00
# 3  2016-04-12  03:00:00
# 4  2016-04-12  04:00:00

# %%
data6['Date']=pd.to_datetime(data6['Date'])

# %%
data6.dtypes
# Out:
# Id                           int64
# ActivityHour        datetime64[ns]
# TotalIntensity               int64
# AverageIntensity           float64
# Date                datetime64[ns]
# Time                        object
# dtype: object

# %%
data6['Hours'] = pd.to_datetime(data6['Time'], format='%H:%M:%S').dt.hour

# %%
data6.head()
# Out:
#            Id        ActivityHour  TotalIntensity  AverageIntensity  \
# 0  1503960366 2016-04-12 00:00:00              20              0.33
# 1  1503960366 2016-04-12 01:00:00               8              0.13
# 2  1503960366 2016-04-12 02:00:00               7              0.12
# 3  1503960366 2016-04-12 03:00:00               0              0.00
# 4  1503960366 2016-04-12 04:00:00               0              0.00
#
#         Date      Time  Hours
# 0 2016-04-12  00:00:00      0
# 1 2016-04-12  01:00:00      1
# 2 2016-04-12  02:00:00      2
# 3 2016-04-12  03:00:00      3
# 4 2016-04-12  04:00:00      4

# %%
data6.dtypes
# Out:
# Id                           int64
# ActivityHour        datetime64[ns]
# TotalIntensity               int64
# AverageIntensity           float64
# Date                datetime64[ns]
# Time                        object
# Hours                        int32
# dtype: object

# %%
data6.drop(['ActivityHour','Time'],axis=1,inplace=True)

# %%
data6.head()
# Out:
#            Id  TotalIntensity  AverageIntensity       Date  Hours
# 0  1503960366              20              0.33 2016-04-12      0
# 1  1503960366               8              0.13 2016-04-12      1
# 2  1503960366               7              0.12 2016-04-12      2
# 3  1503960366               0              0.00 2016-04-12      3
# 4  1503960366               0              0.00 2016-04-12      4

# %%
data6.shape
# Out:
# (22099, 5)

# %%
data6.duplicated().sum()
# Out:
# 0

# %%
data7.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0

# %%
data7.dtypes
# Out:
# Id               int64
# ActivityHour    object
# StepTotal        int64
# dtype: object

# %%
data7.duplicated().sum()
# Out:
# 0

# %%
data7.isna().sum()
# Out:
# Id              0
# ActivityHour    0
# StepTotal       0
# dtype: int64

# %%
data7['ActivityHour']=pd.to_datetime(data7['ActivityHour'])
# Out:
# <ipython-input-59-6699244896f7>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data7['ActivityHour']=pd.to_datetime(data7['ActivityHour'])

# %%
data7.head()
# Out:
#            Id        ActivityHour  StepTotal
# 0  1503960366 2016-04-12 00:00:00        373
# 1  1503960366 2016-04-12 01:00:00        160
# 2  1503960366 2016-04-12 02:00:00        151
# 3  1503960366 2016-04-12 03:00:00          0
# 4  1503960366 2016-04-12 04:00:00          0

# %%
data7['Date'] = pd.to_datetime(data7['ActivityHour']).dt.date
data7['Time'] = pd.to_datetime(data7['ActivityHour']).dt.time

# %%
data7.head()
# Out:
#            Id        ActivityHour  StepTotal        Date      Time
# 0  1503960366 2016-04-12 00:00:00        373  2016-04-12  00:00:00
# 1  1503960366 2016-04-12 01:00:00        160  2016-04-12  01:00:00
# 2  1503960366 2016-04-12 02:00:00        151  2016-04-12  02:00:00
# 3  1503960366 2016-04-12 03:00:00          0  2016-04-12  03:00:00
# 4  1503960366 2016-04-12 04:00:00          0  2016-04-12  04:00:00

# %%
data7['Date']=pd.to_datetime(data7['Date'])

# %%
data7.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# StepTotal                int64
# Date            datetime64[ns]
# Time                    object
# dtype: object

# %%
data7['Hours'] = pd.to_datetime(data7['Time'], format='%H:%M:%S').dt.hour

# %%
data7.head()
# Out:
#            Id        ActivityHour  StepTotal       Date      Time  Hours
# 0  1503960366 2016-04-12 00:00:00        373 2016-04-12  00:00:00      0
# 1  1503960366 2016-04-12 01:00:00        160 2016-04-12  01:00:00      1
# 2  1503960366 2016-04-12 02:00:00        151 2016-04-12  02:00:00      2
# 3  1503960366 2016-04-12 03:00:00          0 2016-04-12  03:00:00      3
# 4  1503960366 2016-04-12 04:00:00          0 2016-04-12  04:00:00      4

# %%
data7.dtypes
# Out:
# Id                       int64
# ActivityHour    datetime64[ns]
# StepTotal                int64
# Date            datetime64[ns]
# Time                    object
# Hours                    int32
# dtype: object

# %%
data7.drop(['ActivityHour','Time'],axis=1,inplace=True)

# %%
data7.head()
# Out:
#            Id  StepTotal       Date  Hours
# 0  1503960366        373 2016-04-12      0
# 1  1503960366        160 2016-04-12      1
# 2  1503960366        151 2016-04-12      2
# 3  1503960366          0 2016-04-12      3
# 4  1503960366          0 2016-04-12      4

# %%
data7.shape
# Out:
# (22099, 4)

# %%
data7.duplicated().sum()
# Out:
# 0

# %%
merg1=pd.merge(data5,data6,on=['Id','Date','Hours'],how='inner')

# %%
merg2=pd.merge(merg1,data7,on=['Id','Date','Hours'],how='inner')

# %%
merg2.head()
# Out:
#            Id  Calories       Date  Hours  TotalIntensity  AverageIntensity  \
# 0  1503960366        81 2016-04-12      0              20              0.33
# 1  1503960366        61 2016-04-12      1               8              0.13
# 2  1503960366        59 2016-04-12      2               7              0.12
# 3  1503960366        47 2016-04-12      3               0              0.00
# 4  1503960366        48 2016-04-12      4               0              0.00
#
#    StepTotal
# 0        373
# 1        160
# 2        151
# 3          0
# 4          0

# %%
merg2.shape
# Out:
# (22099, 7)

# %%
merg2.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd
merg2.to_csv('final_hour_data.csv', index=False)

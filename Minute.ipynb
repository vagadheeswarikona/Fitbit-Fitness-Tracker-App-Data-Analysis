# %%
import pandas as pd
import numpy as np

# %%
data10=pd.read_csv('/content/drive/MyDrive/minuteMETsNarrow_merged.csv')
data8=pd.read_csv('/content/drive/MyDrive/minuteCaloriesNarrow_merged.csv')
data9=pd.read_csv('/content/drive/MyDrive/minuteIntensitiesNarrow_merged.csv')
data11=pd.read_csv('/content/drive/MyDrive/minuteStepsNarrow_merged.csv')

# %%
data8.head()
# Out:
#            Id         ActivityMinute  Calories
# 0  1503960366  4/12/2016 12:00:00 AM    0.7865
# 1  1503960366  4/12/2016 12:01:00 AM    0.7865
# 2  1503960366  4/12/2016 12:02:00 AM    0.7865
# 3  1503960366  4/12/2016 12:03:00 AM    0.7865
# 4  1503960366  4/12/2016 12:04:00 AM    0.7865

# %%
data8.dtypes
# Out:
# Id                  int64
# ActivityMinute     object
# Calories          float64
# dtype: object

# %%
data8.shape
# Out:
# (1325580, 3)

# %%
data8.duplicated().sum()
# Out:
# 0

# %%
data8.isnull().sum()
# Out:
# Id                0
# ActivityMinute    0
# Calories          0
# dtype: int64

# %%
data8['ActivityMinute']=pd.to_datetime(data8['ActivityMinute'])
# Out:
# <ipython-input-12-7eb812a7e7e0>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data8['ActivityMinute']=pd.to_datetime(data8['ActivityMinute'])

# %%
data8.head()
# Out:
#            Id      ActivityMinute  Calories
# 0  1503960366 2016-04-12 00:00:00    0.7865
# 1  1503960366 2016-04-12 00:01:00    0.7865
# 2  1503960366 2016-04-12 00:02:00    0.7865
# 3  1503960366 2016-04-12 00:03:00    0.7865
# 4  1503960366 2016-04-12 00:04:00    0.7865

# %%
data8.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Calories                 float64
# dtype: object

# %%
data8['Date'] = data8['ActivityMinute'].dt.date
data8['Time'] = data8['ActivityMinute'].dt.time

# %%
data8.head()
# Out:
#            Id      ActivityMinute  Calories        Date      Time
# 0  1503960366 2016-04-12 00:00:00    0.7865  2016-04-12  00:00:00
# 1  1503960366 2016-04-12 00:01:00    0.7865  2016-04-12  00:01:00
# 2  1503960366 2016-04-12 00:02:00    0.7865  2016-04-12  00:02:00
# 3  1503960366 2016-04-12 00:03:00    0.7865  2016-04-12  00:03:00
# 4  1503960366 2016-04-12 00:04:00    0.7865  2016-04-12  00:04:00

# %%
data8['Date']=pd.to_datetime(data8['Date'])

# %%
data8.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Calories                 float64
# Date              datetime64[ns]
# Time                      object
# dtype: object

# %%
data8['Time'] = pd.to_datetime(data8['Time'], format='%H:%M:%S').dt.time

# Step 1: Extract hours and minutes
data8['Hour'] = data8['Time'].apply(lambda x: x.hour)
data8['Minute'] = data8['Time'].apply(lambda x: x.minute)

# %%
data8.head()
# Out:
#            Id      ActivityMinute  Calories       Date      Time  Hour  Minute
# 0  1503960366 2016-04-12 00:00:00    0.7865 2016-04-12  00:00:00     0       0
# 1  1503960366 2016-04-12 00:01:00    0.7865 2016-04-12  00:01:00     0       1
# 2  1503960366 2016-04-12 00:02:00    0.7865 2016-04-12  00:02:00     0       2
# 3  1503960366 2016-04-12 00:03:00    0.7865 2016-04-12  00:03:00     0       3
# 4  1503960366 2016-04-12 00:04:00    0.7865 2016-04-12  00:04:00     0       4

# %%
data8.drop(['ActivityMinute'],axis=1,inplace=True)

# %%
data8.drop(['Time'],axis=1,inplace=True)

# %%
data8.head()
# Out:
#            Id  Calories       Date  Hour  Minute
# 0  1503960366    0.7865 2016-04-12     0       0
# 1  1503960366    0.7865 2016-04-12     0       1
# 2  1503960366    0.7865 2016-04-12     0       2
# 3  1503960366    0.7865 2016-04-12     0       3
# 4  1503960366    0.7865 2016-04-12     0       4

# %%
data8.dtypes
# Out:
# Id                   int64
# Calories           float64
# Date        datetime64[ns]
# Hour                 int64
# Minute               int64
# dtype: object

# %%
data9['ActivityMinute']=pd.to_datetime(data9['ActivityMinute'])
# Out:
# <ipython-input-25-3032367e56ab>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data9['ActivityMinute']=pd.to_datetime(data9['ActivityMinute'])

# %%
data9.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Intensity                  int64
# dtype: object

# %%
data9['Date'] = data9['ActivityMinute'].dt.date
data9['Time'] = data9['ActivityMinute'].dt.time

# %%
data9.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Intensity                  int64
# Date                      object
# Time                      object
# dtype: object

# %%
data9['Date']=pd.to_datetime(data9['Date'])

# %%
data9.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Intensity                  int64
# Date              datetime64[ns]
# Time                      object
# dtype: object

# %%
data9['Time'] = pd.to_datetime(data9['Time'], format='%H:%M:%S').dt.time

# Step 1: Extract hours and minutes
data9['Hour'] = data9['Time'].apply(lambda x: x.hour)
data9['Minute'] = data9['Time'].apply(lambda x: x.minute)

# %%
data9.head()
# Out:
#            Id      ActivityMinute  Intensity       Date      Time  Hour  \
# 0  1503960366 2016-04-12 00:00:00          0 2016-04-12  00:00:00     0
# 1  1503960366 2016-04-12 00:01:00          0 2016-04-12  00:01:00     0
# 2  1503960366 2016-04-12 00:02:00          0 2016-04-12  00:02:00     0
# 3  1503960366 2016-04-12 00:03:00          0 2016-04-12  00:03:00     0
# 4  1503960366 2016-04-12 00:04:00          0 2016-04-12  00:04:00     0
#
#    Minute
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4

# %%
data9.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Intensity                  int64
# Date              datetime64[ns]
# Time                      object
# Hour                       int64
# Minute                     int64
# dtype: object

# %%
data9.drop(['ActivityMinute','Time'],axis=1,inplace=True)

# %%
data9.head()
# Out:
#            Id  Intensity       Date  Hour  Minute
# 0  1503960366          0 2016-04-12     0       0
# 1  1503960366          0 2016-04-12     0       1
# 2  1503960366          0 2016-04-12     0       2
# 3  1503960366          0 2016-04-12     0       3
# 4  1503960366          0 2016-04-12     0       4

# %%
data9.dtypes
# Out:
# Id                    int64
# Intensity             int64
# Date         datetime64[ns]
# Hour                  int64
# Minute                int64
# dtype: object

# %%
data10['ActivityMinute']=pd.to_datetime(data10['ActivityMinute'])
# Out:
# <ipython-input-37-43052dae782a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data10['ActivityMinute']=pd.to_datetime(data10['ActivityMinute'])

# %%
data10.head()
# Out:
#            Id      ActivityMinute  METs
# 0  1503960366 2016-04-12 00:00:00    10
# 1  1503960366 2016-04-12 00:01:00    10
# 2  1503960366 2016-04-12 00:02:00    10
# 3  1503960366 2016-04-12 00:03:00    10
# 4  1503960366 2016-04-12 00:04:00    10

# %%
data10.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# METs                       int64
# dtype: object

# %%
data10['Date'] = data10['ActivityMinute'].dt.date
data10['Time'] = data10['ActivityMinute'].dt.time

# %%
data10.head()
# Out:
#            Id      ActivityMinute  METs        Date      Time
# 0  1503960366 2016-04-12 00:00:00    10  2016-04-12  00:00:00
# 1  1503960366 2016-04-12 00:01:00    10  2016-04-12  00:01:00
# 2  1503960366 2016-04-12 00:02:00    10  2016-04-12  00:02:00
# 3  1503960366 2016-04-12 00:03:00    10  2016-04-12  00:03:00
# 4  1503960366 2016-04-12 00:04:00    10  2016-04-12  00:04:00

# %%
data10['Time'] = pd.to_datetime(data10['Time'], format='%H:%M:%S').dt.time

# Step 1: Extract hours and minutes
data10['Hour'] = data10['Time'].apply(lambda x: x.hour)
data10['Minute'] = data10['Time'].apply(lambda x: x.minute)

# %%
data10.head()
# Out:
#            Id      ActivityMinute  METs        Date      Time  Hour  Minute
# 0  1503960366 2016-04-12 00:00:00    10  2016-04-12  00:00:00     0       0
# 1  1503960366 2016-04-12 00:01:00    10  2016-04-12  00:01:00     0       1
# 2  1503960366 2016-04-12 00:02:00    10  2016-04-12  00:02:00     0       2
# 3  1503960366 2016-04-12 00:03:00    10  2016-04-12  00:03:00     0       3
# 4  1503960366 2016-04-12 00:04:00    10  2016-04-12  00:04:00     0       4

# %%
data10.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# METs                       int64
# Date                      object
# Time                      object
# Hour                       int64
# Minute                     int64
# dtype: object

# %%
data10['Date']=pd.to_datetime(data10['Date'])

# %%
data10.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# METs                       int64
# Date              datetime64[ns]
# Time                      object
# Hour                       int64
# Minute                     int64
# dtype: object

# %%
data10.drop(['ActivityMinute','Time'],axis=1,inplace=True)

# %%
data10.dtypes
# Out:
# Id                 int64
# METs               int64
# Date      datetime64[ns]
# Hour               int64
# Minute             int64
# dtype: object

# %%
data10.head()
# Out:
#            Id  METs       Date  Hour  Minute
# 0  1503960366    10 2016-04-12     0       0
# 1  1503960366    10 2016-04-12     0       1
# 2  1503960366    10 2016-04-12     0       2
# 3  1503960366    10 2016-04-12     0       3
# 4  1503960366    10 2016-04-12     0       4

# %%
data11['ActivityMinute']=pd.to_datetime(data11['ActivityMinute'])
# Out:
# <ipython-input-50-22f9f842d2c5>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data11['ActivityMinute']=pd.to_datetime(data11['ActivityMinute'])

# %%
data11.head()
# Out:
#            Id      ActivityMinute  Steps
# 0  1503960366 2016-04-12 00:00:00      0
# 1  1503960366 2016-04-12 00:01:00      0
# 2  1503960366 2016-04-12 00:02:00      0
# 3  1503960366 2016-04-12 00:03:00      0
# 4  1503960366 2016-04-12 00:04:00      0

# %%
data11.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Steps                      int64
# dtype: object

# %%
data11['Date'] = data11['ActivityMinute'].dt.date
data11['Time'] = data11['ActivityMinute'].dt.time

# %%
data11.head()
# Out:
#            Id      ActivityMinute  Steps        Date      Time
# 0  1503960366 2016-04-12 00:00:00      0  2016-04-12  00:00:00
# 1  1503960366 2016-04-12 00:01:00      0  2016-04-12  00:01:00
# 2  1503960366 2016-04-12 00:02:00      0  2016-04-12  00:02:00
# 3  1503960366 2016-04-12 00:03:00      0  2016-04-12  00:03:00
# 4  1503960366 2016-04-12 00:04:00      0  2016-04-12  00:04:00

# %%
data11['Date']=pd.to_datetime(data11['Date'])

# %%
data11['Time'] = pd.to_datetime(data11['Time'], format='%H:%M:%S').dt.time

# Step 1: Extract hours and minutes
data11['Hour'] = data11['Time'].apply(lambda x: x.hour)
data11['Minute'] = data11['Time'].apply(lambda x: x.minute)

# %%
data11.head()
# Out:
#            Id      ActivityMinute  Steps       Date      Time  Hour  Minute
# 0  1503960366 2016-04-12 00:00:00      0 2016-04-12  00:00:00     0       0
# 1  1503960366 2016-04-12 00:01:00      0 2016-04-12  00:01:00     0       1
# 2  1503960366 2016-04-12 00:02:00      0 2016-04-12  00:02:00     0       2
# 3  1503960366 2016-04-12 00:03:00      0 2016-04-12  00:03:00     0       3
# 4  1503960366 2016-04-12 00:04:00      0 2016-04-12  00:04:00     0       4

# %%
data11.dtypes
# Out:
# Id                         int64
# ActivityMinute    datetime64[ns]
# Steps                      int64
# Date              datetime64[ns]
# Time                      object
# Hour                       int64
# Minute                     int64
# dtype: object

# %%
data11.drop(['ActivityMinute','Time'],axis=1,inplace=True)

# %%
data11.head()
# Out:
#            Id  Steps       Date  Hour  Minute
# 0  1503960366      0 2016-04-12     0       0
# 1  1503960366      0 2016-04-12     0       1
# 2  1503960366      0 2016-04-12     0       2
# 3  1503960366      0 2016-04-12     0       3
# 4  1503960366      0 2016-04-12     0       4

# %%
data11.dtypes
# Out:
# Id                 int64
# Steps              int64
# Date      datetime64[ns]
# Hour               int64
# Minute             int64
# dtype: object

# %%
data11.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd
meg1=pd.merge(data8,data9,on=['Id','Date','Hour','Minute'])
meg2=pd.merge(meg1,data10,on=['Id','Date','Hour','Minute'])
meg3=pd.merge(meg2,data11,on=['Id','Date','Hour','Minute'])

# %%
meg3.head()
# Out:
#            Id  Calories       Date  Hour  Minute  Intensity  METs  Steps
# 0  1503960366    0.7865 2016-04-12     0       0          0    10      0
# 1  1503960366    0.7865 2016-04-12     0       1          0    10      0
# 2  1503960366    0.7865 2016-04-12     0       2          0    10      0
# 3  1503960366    0.7865 2016-04-12     0       3          0    10      0
# 4  1503960366    0.7865 2016-04-12     0       4          0    10      0

# %%
meg3.shape
# Out:
# (1325580, 8)

# %%
meg3.dtypes
# Out:
# Id                    int64
# Calories            float64
# Date         datetime64[ns]
# Hour                  int64
# Minute                int64
# Intensity             int64
# METs                  int64
# Steps                 int64
# dtype: object

# %%
meg3.duplicated().sum()
# Out:
# 0

# %%
meg3.isnull().sum()
# Out:
# Id           0
# Calories     0
# Date         0
# Hour         0
# Minute       0
# Intensity    0
# METs         0
# Steps        0
# dtype: int64

# %%
meg3.to_csv('Min_Data_merged.csv',index=False)
